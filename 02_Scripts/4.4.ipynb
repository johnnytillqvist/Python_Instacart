# %% [markdown]
# # Task 4.4

# %% [markdown]
# ## Importing Data

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Creating path
path = r'C:\Users\johnn\Desktop\Instacart Basket Analysis'
path
# Out:
# 'C:\\Users\\johnn\\Desktop\\Instacart Basket Analysis'

# %%
# Importing CSV files using path (orders, products and departments)
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
# Check
print(df_ords.head(1))
print("\n")
print(df_prods.head(1))
print("\n")
print(df_dep.head(1))
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day
# 0   2539329        1    prior             1          2                  8  \
#
#    days_since_prior_order
# 0                     NaN
#
#
#    product_id                product_name  aisle_id  department_id  prices
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
#
#
#   department_id       1      2       3        4        5              6
# 0    department  frozen  other  bakery  produce  alcohol  international  \
#
#            7     8                9  ...            12      13         14
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast  \
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Step 2

# %%
# Changing datatype on user_id column

# %%
df_ords['user_id'] = df_ords['user_id'].astype('str')
print(df_ords['user_id'].dtype)
# Out:
# object

# %% [markdown]
# ## Step 3

# %%
# Changing variable name from order_dow to order_day_of_week

# %%
df_ords.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
df_ords.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
df_ords.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %% [markdown]
# ## Step 4

# %%
# Busiest hours

# %%
highest_freq_hour = df_ords['order_hour_of_day'].value_counts(dropna=False).idxmax()
print("The hour with the highest frequency is:", highest_freq_hour)
# Out:
# The hour with the highest frequency is: 10

# %%
top_3_busiest_hours = df_ords['order_hour_of_day'].value_counts().nlargest(3)
print("The top 3 busiest hours are:")
print(top_3_busiest_hours.to_string(header=False))
# Out:
# The top 3 busiest hours are:
# 10    288418
# 11    284728
# 15    283639

# %% [markdown]
# ## Step 5

# %%
# Determining value of 4 (produce) and creating data dictionary with new header

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6
# 0    department  frozen  other  bakery  produce  alcohol  international  \
#
#            7     8                9  ...            12      13         14
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast  \
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# 4 = produce

# %%
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# ## Step 6

# %%
# Subset containing only breakfast item sales

# %%
df_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name
# 27             28                                  Wheat Chex Cereal  \
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %% [markdown]
# ## Step 7

# %%
# Alcohol, deli, beverages, and meat/seafood

# %%
df_dinner = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
print (df_dinner)
# Out:
#        product_id                                    product_name  aisle_id
# 2               3            Robust Golden Unsweetened Oolong Tea        94  \
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %% [markdown]
# ## Step 8

# %%
# Number of rows (7650)

# %%
num_rows = df_dinner.shape[0]
print(num_rows)
# Out:
# 7650

# %% [markdown]
# ## Step 9

# %%
# user_id (1)

# %%
df_ords_user_id_1 = df_ords[df_ords['user_id']=='1']

# %%
df_ords_user_id_1
# Out:
#     order_id user_id eval_set  order_number  order_day_of_week
# 0    2539329       1    prior             1                  2  \
# 1    2398795       1    prior             2                  3
# 2     473747       1    prior             3                  3
# 3    2254736       1    prior             4                  4
# 4     431534       1    prior             5                  4
# 5    3367565       1    prior             6                  2
# 6     550135       1    prior             7                  1
# 7    3108588       1    prior             8                  1
# 8    2295261       1    prior             9                  1
# 9    2550362       1    prior            10                  4
# 10   1187899       1    train            11                  4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %% [markdown]
# ## Step 10

# %%
# Basic stats for user_id 1

# %%
df_ords_user_id_1.describe()
# Out:
#            order_id  order_number  order_day_of_week  order_hour_of_day
# count  1.100000e+01     11.000000          11.000000          11.000000  \
# mean   1.923450e+06      6.000000           2.636364          10.090909
# std    1.071950e+06      3.316625           1.286291           3.477198
# min    4.315340e+05      1.000000           1.000000           7.000000
# 25%    8.690170e+05      3.500000           1.500000           7.500000
# 50%    2.295261e+06      6.000000           3.000000           8.000000
# 75%    2.544846e+06      8.500000           4.000000          13.000000
# max    3.367565e+06     11.000000           4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %% [markdown]
# ## Step 11 - 14

# %%
# Exporting wrangled data to prepared data folder
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))

# %%
# Export complete
